# %%
import pandas as pd

df = pd.read_csv('../data/processed_data/재무비율_처리완.csv')
feature = df[df.columns[9:-1]]
before_winsor_feature = feature.copy()

# %%
df.columns[9:-1]
# Out:
# Index(['총자본증가율(IFRS)', '유형자산증가율(IFRS)', '투자부동산증가율(IFRS)', '비유동자산증가율(IFRS)',
#        '유동자산증가율(IFRS)', '재고자산증가율(IFRS)', '자기자본증가율(IFRS)', '매출액증가율(IFRS)',
#        '정상영업이익증가율(IFRS)', '순이익증가율(IFRS)',
#        ...
#        '노동소득분배율(IFRS)', '자본분배율(IFRS)', '이윤분배율(IFRS)',
#        '법인세비용차감전(계속사업)손익(IFRS)(백만원)', '인건비(IFRS)(백만원)', '금융비용(IFRS)(백만원)',
#        '임차료(IFRS)(백만원)', '세금과공과(IFRS)(백만원)', '감가상각비(IFRS)(백만원)', '종업원수(IFRS)'],
#       dtype='object', length=141)

# %%
from matplotlib import font_manager, rc
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'

selected_variables = feature
# 5x4 subplot 생성
fig, axes = plt.subplots(9, 17, figsize=(40, 30))
axes = axes.flatten()  # 2D axes 배열을 1D 배열로 변환

for i, var in enumerate(selected_variables):
    # i번째 axes에 i번째 변수의 히스토그램을 그림
    axes[i].boxplot(df[var])
    axes[i].set_title(var)  # 각 히스토그램에 변수 이름을 제목으로 설정

plt.tight_layout()  # subplot 간격 조정
plt.show()
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_23736\996394849.py:17: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()  # subplot 간격 조정
# c:\Users\Master\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df[df.columns[9:-1]].describe()
# Out:
#        총자본증가율(IFRS)  유형자산증가율(IFRS)  투자부동산증가율(IFRS)  비유동자산증가율(IFRS)  \
# count    389.000000     389.000000      389.000000      389.000000
# mean       7.586838      47.788483       15.305990       10.222159
# std       53.813486     487.115703      151.716584       51.118413
# min      -81.910000     -99.520000      -92.310000      -99.470000
# 25%       -4.570000      -6.340000        0.000000       -6.410000
# 50%        2.560000       0.000000        0.000000        1.180000
# 75%       10.800000       9.790000        0.000000       15.920000
# max      922.640000    9039.490000     2133.950000      574.830000
#
#        유동자산증가율(IFRS)  재고자산증가율(IFRS)  자기자본증가율(IFRS)  매출액증가율(IFRS)  \
# count     389.000000     389.000000     389.000000    389.000000
# mean       13.928689      67.144961       7.607095     10.814190
# std        94.968643     840.520057      51.195959     57.445574
# min       -94.560000     -98.690000     -92.940000    -98.090000
# 25%        -9.890000     -12.730000      -7.720000    -10.330000
# 50%         1.900000       0.000000       1.600000      1.240000
# 75%        17.200000      17.850000      11.600000     15.770000
# max      1591.630000   16282.800000     499.400000    485.070000
#
#        정상영업이익증가율(IFRS)  순이익증가율(IFRS)  ...  노동소득분배율(IFRS)   자본분배율(IFRS)  \
# count       389.000000    389.000000  ...     389.000000    389.000000
# mean        304.412185     -2.762262  ...     161.160154    -80.954499
# std        5887.125737    299.396295  ...    1477.557172   1475.930332
# min       -1542.640000  -5320.500000  ...       0.000000 -28477.690000
# 25%           0.000000      0.000000  ...      28.020000      0.000000
# 50%           0.000000      0.000000  ...      55.230000     26.840000
# 75%           0.550000      0.000000  ...      76.440000     49.370000
# max      116066.340000   1352.070000  ...   28577.690000     92.530000
#
#         이윤분배율(IFRS)  법인세비용차감전(계속사업)손익(IFRS)(백만원)  인건비(IFRS)(백만원)  \
# count    389.000000                 3.890000e+02    3.890000e+02
# mean    -232.377558                 1.559327e+04    9.478764e+04
# std     2738.067051                 2.784824e+05    2.875997e+05
# min   -50846.420000                -3.124361e+06   -2.386364e+04
# 25%      -13.330000                -1.002139e+04    5.570410e+03
# 50%        0.000000                 2.779400e+02    1.280991e+04
# 75%       21.320000                 1.066846e+04    3.572547e+04
# max       77.600000                 1.571030e+06    2.055868e+06
#
#        금융비용(IFRS)(백만원)  임차료(IFRS)(백만원)  세금과공과(IFRS)(백만원)  감가상각비(IFRS)(백만원)  \
# count       389.000000      389.000000        389.000000        389.000000
# mean       9165.102982     5618.652057        832.450591      22192.300437
# std       45912.801525    43766.772036       5145.486096      65427.520577
# min      -54363.000000     -194.640000          0.000000          0.000000
# 25%         128.840000        0.000000          0.000000       1350.230000
# 50%        1174.800000        0.000000          0.000000       3040.440000
# 75%        3411.040000      240.620000          0.000000       9785.160000
# max      459499.000000   602155.270000      62921.000000     550894.000000
#
#          종업원수(IFRS)
# count    389.000000
# mean     768.066838
# std     1886.967186
# min        0.000000
# 25%       83.000000
# 50%      187.000000
# 75%      380.000000
# max    13602.000000
#
# [8 rows x 141 columns]

# %% [markdown]
# ## 2. 이상치 처리
# 컬럼마다 이상치의 분포가 상하위, 상위, 하위에 분포하는 비율이 다르기 때문에 각자 다르게 이상치 조정 필요
# - 상하위 고르게 분포한 컬럼
# - 상위에 분포한 컬럼
# - 하위에 분포한 컬럼

# %%
import numpy as np
from scipy.stats import mstats
import statsmodels.api as sm

# 중앙값과 절대 중앙값 편차 (MAD) 계산 함수
def mad_based_outliers(df, threshold=3):        # 임계값은 3으로 설정
    median = np.median(df)
    mad = sm.robust.scale.mad(df)
    mad_scaled = np.abs(df - median) / mad if mad != 0 else 0
    return mad_scaled > threshold

# 윈저라이징 조건 설정 함수
def apply_winsorization_based_on_outliers(df, threshold=3):
    winsorization_info = {}  # 각 컬럼별 윈저라이징 방식을 저장할 딕셔너리

    for column in df.columns:
        # MAD 기반 이상치 탐지
        outliers_mask = mad_based_outliers(df[column], threshold)
        outliers_high = np.sum(outliers_mask & (df[column] > np.median(df[column])))
        outliers_low = np.sum(outliers_mask & (df[column] < np.median(df[column])))

        # 조건에 따라 윈저라이징 방식 결정
        if outliers_high > 0 and outliers_low == 0:  # 상위 이상치만 있을 때
            df[column] = mstats.winsorize(df[column], limits=(0, 0.02))  # 상위 2%만 윈저라이징
            winsorization_info[column] = "상위 2% 윈저라이징"
        elif outliers_low > 0 and outliers_high == 0:  # 하위 이상치만 있을 때
            df[column] = mstats.winsorize(df[column], limits=(0.02, 0))  # 하위 2%만 윈저라이징
            winsorization_info[column] = "하위 2% 윈저라이징"
        elif outliers_high > 0 and outliers_low > 0:  # 상하위 이상치가 모두 있을 때
            df[column] = mstats.winsorize(df[column], limits=(0.01, 0.01))  # 상하위 1%씩 윈저라이징
            winsorization_info[column] = "상하위 1% 윈저라이징"
    return winsorization_info

# %%
winsorization_info = apply_winsorization_based_on_outliers(feature)
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_23736\2069085115.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = mstats.winsorize(df[column], limits=(0.01, 0.01))  # 상하위 1%씩 윈저라이징
# C:\Users\Master\AppData\Local\Temp\ipykernel_23736\2069085115.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = mstats.winsorize(df[column], limits=(0, 0.02))  # 상위 2%만 윈저라이징
# C:\Users\Master\AppData\Local\Temp\ipykernel_23736\2069085115.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = mstats.winsorize(df[column], limits=(0.02, 0))  # 하위 2%만 윈저라이징

# %%
winsorization_info
# Out:
# {'총자본증가율(IFRS)': '상하위 1% 윈저라이징',
#  '유형자산증가율(IFRS)': '상하위 1% 윈저라이징',
#  '비유동자산증가율(IFRS)': '상하위 1% 윈저라이징',
#  '유동자산증가율(IFRS)': '상하위 1% 윈저라이징',
#  '재고자산증가율(IFRS)': '상하위 1% 윈저라이징',
#  '자기자본증가율(IFRS)': '상하위 1% 윈저라이징',
#  '매출액증가율(IFRS)': '상하위 1% 윈저라이징',
#  '종업원1인당 부가가치증가율(IFRS)': '상하위 1% 윈저라이징',
#  '종업원수증가율(IFRS)': '상하위 1% 윈저라이징',
#  '종업원1인당 매출액증가율(IFRS)': '상하위 1% 윈저라이징',
#  '종업원1인당 인건비증가율(IFRS)': '상하위 1% 윈저라이징',
#  '매출액총이익률(IFRS)': '상하위 1% 윈저라이징',
#  '매출액정상영업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '매출액순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '총자본사업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '총자본정상영업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '총자본순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '자기자본정상영업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '자기자본순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '경영자본정상영업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '경영자본순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '자본금정상영업이익률(IFRS)': '상하위 1% 윈저라이징',
#  '자본금순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '매출원가 대 매출액비율(IFRS)': '상하위 1% 윈저라이징',
#  '영업비용 대 영업수익비율(IFRS)': '상하위 1% 윈저라이징',
#  '기타손익비률(IFRS)': '상하위 1% 윈저라이징',
#  '금융손익비율(IFRS)': '상하위 1% 윈저라이징',
#  '금융비용부담률(IFRS)': '상하위 1% 윈저라이징',
#  '외환이익 대 매출액비율(IFRS)': '상하위 1% 윈저라이징',
#  '광고선전비 대 매출액비율(IFRS)': '상위 2% 윈저라이징',
#  '세금과공과 대 세금과공과 차감전순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '기업순이익률(IFRS)': '상하위 1% 윈저라이징',
#  '수지비율(관계기업투자손익 제외)(IFRS)': '상하위 1% 윈저라이징',
#  '인건비 대 총비용비율(IFRS)': '상하위 1% 윈저라이징',
#  '금융비용 대 총비용비율(IFRS)': '상하위 1% 윈저라이징',
#  '감가상각비 대 총비용비율(IFRS)': '상위 2% 윈저라이징',
#  '감가상각률(IFRS)': '상위 2% 윈저라이징',
#  '누적감가상각률(IFRS)': '상위 2% 윈저라이징',
#  '이자부담률(IFRS)': '상하위 1% 윈저라이징',
#  '지급이자율(IFRS)': '상위 2% 윈저라이징',
#  '차입금평균이자율(IFRS)': '상위 2% 윈저라이징',
#  '유보율(IFRS)': '상위 2% 윈저라이징',
#  '사내유보 대 자기자본비율(IFRS)': '하위 2% 윈저라이징',
#  '적립금비율(재정비율)(IFRS)': '상하위 1% 윈저라이징',
#  '1주당매출액(IFRS)(원)': '상위 2% 윈저라이징',
#  '1주당순이익(IFRS)(원)': '상하위 1% 윈저라이징',
#  '1주당 CASH FLOW(IFRS)(원)': '상하위 1% 윈저라이징',
#  '1주당순자산(IFRS)(원)': '상위 2% 윈저라이징',
#  '1주당정상영업이익(IFRS)(원)': '상하위 1% 윈저라이징',
#  '유동자산 대 비유동자산비율(IFRS)': '상위 2% 윈저라이징',
#  '당좌자산구성비율(IFRS)': '상위 2% 윈저라이징',
#  '타인자본구성비율(IFRS)': '상위 2% 윈저라이징',
#  '자기자본배율(IFRS)': '상위 2% 윈저라이징',
#  '비유동비율(IFRS)': '상위 2% 윈저라이징',
#  '비유동장기적합률(IFRS)': '상위 2% 윈저라이징',
#  '유동비율(IFRS)': '상위 2% 윈저라이징',
#  '당좌비율(IFRS)': '상위 2% 윈저라이징',
#  '현금비율(IFRS)': '상위 2% 윈저라이징',
#  '매출채권비율(IFRS)': '상위 2% 윈저라이징',
#  '재고자산 대 순운전자본비율(IFRS)': '상위 2% 윈저라이징',
#  '매출채권 대 매입채무비율(IFRS)': '상위 2% 윈저라이징',
#  '매출채권 대 상,제품비율(IFRS)': '상위 2% 윈저라이징',
#  '매입채무 대 재고자산비율(IFRS)': '상위 2% 윈저라이징',
#  '부채비율(IFRS)': '상위 2% 윈저라이징',
#  '유동부채비율(IFRS)': '상위 2% 윈저라이징',
#  '비유동부채비율(IFRS)': '상위 2% 윈저라이징',
#  '비유동부채 대 순운전자본비율(IFRS)': '상위 2% 윈저라이징',
#  '순운전자본비율(IFRS)': '하위 2% 윈저라이징',
#  '차입금의존도(IFRS)': '상위 2% 윈저라이징',
#  '차입금비율(IFRS)': '상위 2% 윈저라이징',
#  '이자보상배율(이자비용)(IFRS)': '상하위 1% 윈저라이징',
#  '이자보상배율(순금융비용)(IFRS)': '상하위 1% 윈저라이징',
#  '유보액대비율(IFRS)': '하위 2% 윈저라이징',
#  '유보액 대 납입자본배율(IFRS)': '상위 2% 윈저라이징',
#  '유동자산집중도(IFRS)': '상위 2% 윈저라이징',
#  '비유동자산집중도(IFRS)': '상위 2% 윈저라이징',
#  '투자집중도(IFRS)': '상위 2% 윈저라이징',
#  'CASH FLOW 대 부채비율(IFRS)': '상하위 1% 윈저라이징',
#  'CASH FLOW 대 차입금비율(IFRS)': '상하위 1% 윈저라이징',
#  'CASH FLOW 대 총자본비율(IFRS)': '상하위 1% 윈저라이징',
#  'CASH FLOW 대 매출액비율(IFRS)': '상하위 1% 윈저라이징',
#  '정상영업이익대비이자보상배율(IFRS)': '상하위 1% 윈저라이징',
#  '총자본회전률(IFRS)': '상위 2% 윈저라이징',
#  '경영자본회전률(IFRS)': '상위 2% 윈저라이징',
#  '자기자본회전률(IFRS)': '상위 2% 윈저라이징',
#  '자본금회전률(IFRS)': '상위 2% 윈저라이징',
#  '타인자본회전률(IFRS)': '상위 2% 윈저라이징',
#  '매입채무회전률(IFRS)': '상위 2% 윈저라이징',
#  '매입채무회전기간(IFRS)': '상위 2% 윈저라이징',
#  '유동자산회전률(IFRS)': '상위 2% 윈저라이징',
#  '당좌자산회전률(IFRS)': '상위 2% 윈저라이징',
#  '재고자산회전률(IFRS)': '상위 2% 윈저라이징',
#  '재고자산회전기간(IFRS)': '상위 2% 윈저라이징',
#  '상품,제품회전률(IFRS)': '상위 2% 윈저라이징',
#  '원,부재료회전률(IFRS)': '상위 2% 윈저라이징',
#  '재공품회전률(IFRS)': '상위 2% 윈저라이징',
#  '매출채권회전률(IFRS)': '상위 2% 윈저라이징',
#  '매출채권회전기간(IFRS)': '상위 2% 윈저라이징',
#  '비유동자산회전률(IFRS)': '상위 2% 윈저라이징',
#  '유형자산회전율(IFRS)': '상위 2% 윈저라이징',
#  '순운전자본회전률(IFRS)': '상위 2% 윈저라이징',
#  '1회전기간(IFRS)': '상위 2% 윈저라이징',
#  '부가가치(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '종업원1인당 부가가치(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '종업원1인당 매출액(IFRS)(백만원)': '상위 2% 윈저라이징',
#  '종업원1인당 정상영업이익(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '종업원1인당 순이익(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '종업원1인당 인건비(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '노동장비율(IFRS)': '상위 2% 윈저라이징',
#  '기계장비율(IFRS)': '상위 2% 윈저라이징',
#  '자본집약도(IFRS)': '상위 2% 윈저라이징',
#  '총자본투자효율(IFRS)': '상하위 1% 윈저라이징',
#  '설비투자효율(IFRS)': '상하위 1% 윈저라이징',
#  '기계투자효율(IFRS)': '상하위 1% 윈저라이징',
#  '부가가치율(IFRS)': '상하위 1% 윈저라이징',
#  '노동소득분배율(IFRS)': '상위 2% 윈저라이징',
#  '자본분배율(IFRS)': '하위 2% 윈저라이징',
#  '이윤분배율(IFRS)': '하위 2% 윈저라이징',
#  '법인세비용차감전(계속사업)손익(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '인건비(IFRS)(백만원)': '상위 2% 윈저라이징',
#  '금융비용(IFRS)(백만원)': '상하위 1% 윈저라이징',
#  '감가상각비(IFRS)(백만원)': '상위 2% 윈저라이징',
#  '종업원수(IFRS)': '상위 2% 윈저라이징'}

# %%
feature.describe()
# Out:
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# c:\Users\Master\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
#        총자본증가율(IFRS)  유형자산증가율(IFRS)  투자부동산증가율(IFRS)  비유동자산증가율(IFRS)  \
# count    389.000000     389.000000      389.000000      389.000000
# mean       5.467969      24.847069       15.305990        9.195913
# std       26.823317     151.226670      151.716584       42.308560
# min      -59.910000     -90.400000      -92.310000      -73.430000
# 25%       -4.570000      -6.340000        0.000000       -6.410000
# 50%        2.560000       0.000000        0.000000        1.180000
# 75%       10.800000       9.790000        0.000000       15.920000
# max      138.880000    1244.130000     2133.950000      218.200000
#
#        유동자산증가율(IFRS)  재고자산증가율(IFRS)  자기자본증가율(IFRS)  매출액증가율(IFRS)  \
# count     389.000000     389.000000     389.000000    389.000000
# mean        9.247506      24.428509       6.076684      9.722211
# std        40.472146     134.123793      39.631526     49.543349
# min       -64.220000     -90.990000     -81.860000    -81.760000
# 25%        -9.890000     -12.730000      -7.720000    -10.330000
# 50%         1.900000       0.000000       1.600000      1.240000
# 75%        17.200000      17.850000      11.600000     15.770000
# max       196.210000    1121.250000     221.650000    280.100000
#
#        정상영업이익증가율(IFRS)  순이익증가율(IFRS)  ...  노동소득분배율(IFRS)  자본분배율(IFRS)  \
# count       389.000000    389.000000  ...     389.000000   389.000000
# mean        304.412185     -2.762262  ...      67.970848    12.234807
# std        5887.125737    299.396295  ...      75.481083    67.759073
# min       -1542.640000  -5320.500000  ...       0.000000  -308.510000
# 25%           0.000000      0.000000  ...      28.020000     0.000000
# 50%           0.000000      0.000000  ...      55.230000    26.840000
# 75%           0.550000      0.000000  ...      76.440000    49.370000
# max      116066.340000   1352.070000  ...     408.510000    92.530000
#
#        이윤분배율(IFRS)  법인세비용차감전(계속사업)손익(IFRS)(백만원)  인건비(IFRS)(백만원)  \
# count   389.000000                 3.890000e+02    3.890000e+02
# mean    -33.206658                 2.028244e+04    9.031293e+04
# std     128.362922                 2.256646e+05    2.605101e+05
# min    -641.990000                -1.010005e+06   -2.386364e+04
# 25%     -13.330000                -1.002139e+04    5.570410e+03
# 50%       0.000000                 2.779400e+02    1.280991e+04
# 75%      21.320000                 1.066846e+04    3.572547e+04
# max      77.600000                 1.322484e+06    1.540530e+06
#
#        금융비용(IFRS)(백만원)  임차료(IFRS)(백만원)  세금과공과(IFRS)(백만원)  감가상각비(IFRS)(백만원)  \
# count       389.000000      389.000000        389.000000        389.000000
# mean       7631.461028     5618.652057        832.450591      19010.608895
# std       31730.394902    43766.772036       5145.486096      45897.161855
# min      -41923.930000     -194.640000          0.000000          0.000000
# 25%         128.840000        0.000000          0.000000       1350.230000
# 50%        1174.800000        0.000000          0.000000       3040.440000
# 75%        3411.040000      240.620000          0.000000       9785.160000
# max      244876.000000   602155.270000      62921.000000     240711.000000
#
#         종업원수(IFRS)
# count   389.000000
# mean    700.614396
# std    1515.091726
# min       0.000000
# 25%      83.000000
# 50%     187.000000
# 75%     380.000000
# max    7468.000000
#
# [8 rows x 141 columns]

# %%
before_winsor_feature.describe()
# Out:
#        총자본증가율(IFRS)  유형자산증가율(IFRS)  투자부동산증가율(IFRS)  비유동자산증가율(IFRS)  \
# count    389.000000     389.000000      389.000000      389.000000
# mean       7.586838      47.788483       15.305990       10.222159
# std       53.813486     487.115703      151.716584       51.118413
# min      -81.910000     -99.520000      -92.310000      -99.470000
# 25%       -4.570000      -6.340000        0.000000       -6.410000
# 50%        2.560000       0.000000        0.000000        1.180000
# 75%       10.800000       9.790000        0.000000       15.920000
# max      922.640000    9039.490000     2133.950000      574.830000
#
#        유동자산증가율(IFRS)  재고자산증가율(IFRS)  자기자본증가율(IFRS)  매출액증가율(IFRS)  \
# count     389.000000     389.000000     389.000000    389.000000
# mean       13.928689      67.144961       7.607095     10.814190
# std        94.968643     840.520057      51.195959     57.445574
# min       -94.560000     -98.690000     -92.940000    -98.090000
# 25%        -9.890000     -12.730000      -7.720000    -10.330000
# 50%         1.900000       0.000000       1.600000      1.240000
# 75%        17.200000      17.850000      11.600000     15.770000
# max      1591.630000   16282.800000     499.400000    485.070000
#
#        정상영업이익증가율(IFRS)  순이익증가율(IFRS)  ...  노동소득분배율(IFRS)   자본분배율(IFRS)  \
# count       389.000000    389.000000  ...     389.000000    389.000000
# mean        304.412185     -2.762262  ...     161.160154    -80.954499
# std        5887.125737    299.396295  ...    1477.557172   1475.930332
# min       -1542.640000  -5320.500000  ...       0.000000 -28477.690000
# 25%           0.000000      0.000000  ...      28.020000      0.000000
# 50%           0.000000      0.000000  ...      55.230000     26.840000
# 75%           0.550000      0.000000  ...      76.440000     49.370000
# max      116066.340000   1352.070000  ...   28577.690000     92.530000
#
#         이윤분배율(IFRS)  법인세비용차감전(계속사업)손익(IFRS)(백만원)  인건비(IFRS)(백만원)  \
# count    389.000000                 3.890000e+02    3.890000e+02
# mean    -232.377558                 1.559327e+04    9.478764e+04
# std     2738.067051                 2.784824e+05    2.875997e+05
# min   -50846.420000                -3.124361e+06   -2.386364e+04
# 25%      -13.330000                -1.002139e+04    5.570410e+03
# 50%        0.000000                 2.779400e+02    1.280991e+04
# 75%       21.320000                 1.066846e+04    3.572547e+04
# max       77.600000                 1.571030e+06    2.055868e+06
#
#        금융비용(IFRS)(백만원)  임차료(IFRS)(백만원)  세금과공과(IFRS)(백만원)  감가상각비(IFRS)(백만원)  \
# count       389.000000      389.000000        389.000000        389.000000
# mean       9165.102982     5618.652057        832.450591      22192.300437
# std       45912.801525    43766.772036       5145.486096      65427.520577
# min      -54363.000000     -194.640000          0.000000          0.000000
# 25%         128.840000        0.000000          0.000000       1350.230000
# 50%        1174.800000        0.000000          0.000000       3040.440000
# 75%        3411.040000      240.620000          0.000000       9785.160000
# max      459499.000000   602155.270000      62921.000000     550894.000000
#
#          종업원수(IFRS)
# count    389.000000
# mean     768.066838
# std     1886.967186
# min        0.000000
# 25%       83.000000
# 50%      187.000000
# 75%      380.000000
# max    13602.000000
#
# [8 rows x 141 columns]

# %% [markdown]
# 이상치 처리 후 시각화

# %%
selected_variables = feature
# 5x4 subplot 생성
fig, axes = plt.subplots(9, 17, figsize=(40, 30))
axes = axes.flatten()  # 2D axes 배열을 1D 배열로 변환

for i, var in enumerate(selected_variables):
    # i번째 axes에 i번째 변수의 히스토그램을 그림
    axes[i].boxplot(df[var])
    axes[i].set_title(var)  # 각 히스토그램에 변수 이름을 제목으로 설정

plt.tight_layout()  # subplot 간격 조정
plt.show()
# Out:
# C:\Users\Master\AppData\Local\Temp\ipykernel_23736\3925463789.py:11: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()  # subplot 간격 조정
# c:\Users\Master\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
